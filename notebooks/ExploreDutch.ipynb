# %%
# %load_ext autoreload

# %autoreload 2

# %%
import spacy
import codecs
from __future__ import unicode_literals, print_function

# %%
nlp_nl = spacy.load('nl')
vocab_nl = nlp_nl.vocab
print(len(vocab_nl.strings))
# Out:
# 263751

# %%
text = u'De kat zit in de rodondendron.'
doc =  nlp_nl(text)

# %%
for word in doc:
    print(word.text, word.cluster, word.prob, word.is_oov)
# Out:
# De 13 -4.96845006943 False
# kat 11 -8.19717407227 False
# zit 177 -8.19717407227 False
# in 57 -3.92010498047 False
# de 15 -3.1118144989 False
# rodondendron 0 -8.19717407227 True
# . 5 -3.25676512718 False

# %%
word.vector
# Out:
# array([  4.83505994e-01,   1.07370000e-02,  -2.10099995e-01,
#          1.12910001e-02,   7.75242984e-01,  -9.55186009e-01,
#          1.36987999e-01,  -3.83432001e-01,  -3.57504994e-01,
#         -1.28650296e+00,   1.62165999e-01,   4.18954998e-01,
#          9.29942012e-01,  -1.97019994e-01,  -1.00110698e+00,
#          5.54000027e-04,  -9.65200007e-01,  -7.19156027e-01,
#          1.44516006e-01,  -3.27129990e-01,  -6.85171008e-01,
#         -3.44940990e-01,  -3.84126991e-01,  -8.13250020e-02,
#         -1.65345997e-01,   4.29675996e-01,   6.04939997e-01,
#         -4.09049988e-01,   7.19168007e-01,   3.81787002e-01,
#         -2.75135010e-01,  -1.27554500e+00,  -4.24170010e-02,
#         -3.69060993e-01,  -1.99986994e-01,   4.02083993e-01,
#         -7.15600001e-03,  -7.92176008e-01,  -3.89768004e-01,
#         -8.98374021e-01,  -3.77301008e-01,   2.96191990e-01,
#         -1.04364705e+00,  -2.52736986e-01,   4.61896986e-01,
# ...
